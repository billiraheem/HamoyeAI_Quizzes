# %%
import pandas as pd
import numpy as np


file = open(r"C:\\Users\\User\\Documents\GitHub\HamoyeAI_Quizzes\FoodBalanceSheets_E_Africa_NOFLAG.csv")
df = pd.read_csv(file, encoding = "latin-1")
print(df.columns)
print('***************************************************************************************')
print('                               ')

#finding the number and percentage of missing data in the year 2014
print(df['Y2014'].isna().sum())
print((df['Y2014'].isna().sum()) / df.shape[0] * 100)
print('***************************************************************************************')
print('                               ')

#checking which year has the least correlation with 'Element Code'
#print(df.corr(method = "pearson"))

#selecting column 'Y2017' and 'Area' then grouping by 'Area'
Q6 = df[['Y2017', 'Area']].groupby('Area')
Q6_sum = Q6.sum()
print(Q6_sum)
print(Q6_sum.min())
print('***************************************************************************************')
print('                               ')

#mean and std for the Y2017
print(df['Y2017'].describe())
print('***************************************************************************************')
print('                               ')

#Question 12
Q12 = df[['Y2015', 'Y2018', 'Item']].groupby('Item')
print(Q12.sum())
print('***************************************************************************************')
print('                               ')

#what year has highest stock variation 
Q13 = df[['Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018', 'Element']].groupby('Element')
Q13_sum = Q13.sum()
print(Q13_sum.min())
print('***************************************************************************************')
print('                               ')

#
Q15 = df[['Y2017', 'Element']].groupby('Element')
print(Q15.sum())
print('***************************************************************************************')
print('                               ')

#questio 16
print(Q6_sum.max())
print('***************************************************************************************')
print('                               ')

#find total number of unique countries
countries = df.value_counts('Area')
print(countries)
# Out:
# Index(['Area Code', 'Area', 'Item Code', 'Item', 'Element Code', 'Element',
#        'Unit', 'Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018'],
#       dtype='object')
# ***************************************************************************************
#
# 1589
# 2.6073544131401474
# ***************************************************************************************
#
#                                   Y2017
# Area
# Algeria                       325644.27
# Angola                        229159.57
# Benin                         124771.22
# Botswana                       22101.30
# Burkina Faso                  101855.07
# Cabo Verde                     14650.74
# Cameroon                      232030.43
# Central African Republic       29937.00
# Chad                           71594.68
# Comoros                           59.84
# Congo                          41181.68
# Côte d'Ivoire                 224599.01
# Djibouti                       22729.91
# ...
